# %% [markdown]
# <a href="https://colab.research.google.com/github/TrillDaBest/TrillDaBest/blob/main/sonoma_shelter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # To be updated (TITLE)

# %% [markdown]
# #### Author: Ronit Kumar
# Date : 10/14/2025

# %% [markdown]
# ## Introduction

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Initial Data Exploration

# %%
df = pd.read_csv('https://raw.githubusercontent.com/grbruns/cst383/master/sonoma-shelter-13-october-2025.csv')

# %% [markdown]
# ## Data preprocessing

# %% [markdown]
# ## Data exploration and visualization

# %% [markdown]
# ## Conclusions
